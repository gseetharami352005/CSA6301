# %% [markdown]
# <a href="https://colab.research.google.com/github/gseetharami352005/CSA6301/blob/main/exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Example usage:
target = '127.0.0.1'  # You can replace this with a different IP or hostname, e.g., 'scanme.nmap.org'
start = 1
end = 100

open_ports_found = scan_ports(target, start, end)

if open_ports_found:
    print(f"Open ports on {target}: {open_ports_found}")
else:
    print(f"No open ports found on {target} in the range {start}-{end}.")
# Out:
# Starting port scan on 127.0.0.1 from port 1 to 100...
#
# Scan completed. Found 0 open ports.
# No open ports found on 127.0.0.1 in the range 1-100.
