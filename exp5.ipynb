# %% [markdown]
# <a href="https://colab.research.google.com/github/gseetharami352005/CSA6301/blob/main/exp5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List of domain names to resolve
my_domains = [
    'google.com',
    'wikipedia.org',
    'nonexistent-domain-123456789.com', # An example of a domain that likely won't resolve
    'python.org',
    'bing.com'
]

# Resolve the domains
resolved_addresses = resolve_domains_to_ips(my_domains)

# Display the results
print("\n--- Resolved IP Addresses ---")
if resolved_addresses:
    for domain, ip in resolved_addresses.items():
        print(f"Domain: {domain}, IP Address: {ip}")
else:
    print("No domains were successfully resolved.")
# Out:
# Starting domain resolution...
#   google.com -> 173.194.203.102
#   wikipedia.org -> 198.35.26.224
#   Could not resolve domain: nonexistent-domain-123456789.com
#   python.org -> 151.101.64.223
#   bing.com -> 150.171.27.10
#
# Domain resolution completed.
#
# --- Resolved IP Addresses ---
# Domain: google.com, IP Address: 173.194.203.102
# Domain: wikipedia.org, IP Address: 198.35.26.224
# Domain: python.org, IP Address: 151.101.64.223
# Domain: bing.com, IP Address: 150.171.27.10
