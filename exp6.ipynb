# %% [markdown]
# <a href="https://colab.research.google.com/github/gseetharami352005/CSA6301/blob/main/exp6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Traffic Log Scanner for Malicious IPs (IoCs)

# %%
# Execute the scan
flagged_results = scan_traffic_log_for_iocs(traffic_log, malicious_ips)

print("\n--- Scan Summary ---")
if flagged_results:
    print(f"Found {len(flagged_results)} suspicious log entries:\n")
    for result in flagged_results:
        print(f"  Log Index: {result['log_index']}")
        print(f"  Malicious IP: {result['malicious_ip']}")
        print(f"  Log Entry: {result['log_entry']}\n")
else:
    print("No malicious IP addresses were found in the traffic log.")
# Out:
# Starting log scan for malicious IPs...
#   FLAGGED: Malicious IP '10.0.0.5' found in log entry 1: [2023-10-27 10:00:02] WARNING Failed login attempt from 10.0.0.5. User: admin
#   FLAGGED: Malicious IP '203.0.113.45' found in log entry 3: [2023-10-27 10:00:04] ERROR Unauthorized access from 203.0.113.45!
#   FLAGGED: Malicious IP '203.0.113.12' found in log entry 5: [2023-10-27 10:00:06] ALERT Possible intrusion from 203.0.113.12. Scanning detected!
#   FLAGGED: Malicious IP '172.16.0.250' found in log entry 7: [2023-10-27 10:00:08] CRITICAL Malware detected from 172.16.0.250. System compromised.
#   FLAGGED: Malicious IP '198.51.100.1' found in log entry 9: [2023-10-27 10:00:10] INFO Access granted to 198.51.100.1. Resource: /internal/api
# Log scan completed.
#
# --- Scan Summary ---
# Found 5 suspicious log entries:
#
#   Log Index: 1
#   Malicious IP: 10.0.0.5
#   Log Entry: [2023-10-27 10:00:02] WARNING Failed login attempt from 10.0.0.5. User: admin
#
#   Log Index: 3
# ...
