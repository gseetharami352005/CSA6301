# %% [markdown]
# <a href="https://colab.research.google.com/github/gseetharami352005/CSA6301/blob/main/exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Example 1: A seemingly legitimate URL
url1 = "https://www.google.com/search?q=phishing+detection+python"
is_suspicious, reasons = analyze_url_for_phishing(url1)
print(f"URL: {url1}")
if is_suspicious:
    print(f"  Status: SUSPICIOUS! Reasons: {'; '.join(reasons)}")
else:
    print("  Status: Looks legitimate.")
print("---\n")

# Example 2: URL with HTTP, IP address in hostname, and deceptive keywords
url2 = "http://192.168.1.100/secure-login/index.php?id=123"
is_suspicious, reasons = analyze_url_for_phishing(url2)
print(f"URL: {url2}")
if is_suspicious:
    print(f"  Status: SUSPICIOUS! Reasons: {'; '.join(reasons)}")
else:
    print("  Status: Looks legitimate.")
print("---\n")

# Example 3: URL using '@' symbol for obfuscation
url3 = "https://www.google.com@phishing.example.com/login"
is_suspicious, reasons = analyze_url_for_phishing(url3)
print(f"URL: {url3}")
if is_suspicious:
    print(f"  Status: SUSPICIOUS! Reasons: {'; '.join(reasons)}")
else:
    print("  Status: Looks legitimate.")
print("---\n")

# Example 4: URL with multiple subdomains to mimic a well-known site
url4 = "https://secure.login.paypal.com.evilphish.net/account/update"
is_suspicious, reasons = analyze_url_for_phishing(url4)
print(f"URL: {url4}")
if is_suspicious:
    print(f"  Status: SUSPICIOUS! Reasons: {'; '.join(reasons)}")
else:
    print("  Status: Looks legitimate.")
print("---\n")

# Example 5: A very long URL (could be legitimate, but flagged by length)
url5 = "https://docs.python.org/3/library/urllib.parse.html?highlight=urlparse#url-parsing-with-urlparse-and-urlsplit-this-is-a-very-long-path-to-test-the-length-indicator-for-phishing-detection-examples-in-python-with-many-words-and-characters-to-trigger-the-length-check"
is_suspicious, reasons = analyze_url_for_phishing(url5)
print(f"URL: {url5}")
if is_suspicious:
    print(f"  Status: SUSPICIOUS! Reasons: {'; '.join(reasons)}")
else:
    print("  Status: Looks legitimate.")
print("---\n")
# Out:
# URL: https://www.google.com/search?q=phishing+detection+python
#   Status: Looks legitimate.
# ---
#
# URL: http://192.168.1.100/secure-login/index.php?id=123
#   Status: SUSPICIOUS! Reasons: Uses HTTP instead of HTTPS (less secure connection).; Hostname is an IP address (192.168.1.100), not a readable domain name.; Has multiple subdomains (3 parts), potentially for deception.; Contains deceptive keywords in path/query (e.g., 'login', 'verify').
# ---
#
# URL: https://www.google.com@phishing.example.com/login
#   Status: SUSPICIOUS! Reasons: Contains '@' symbol, often used for credential embedding or confusion.; Contains deceptive keywords in path/query (e.g., 'login', 'verify').
# ---
#
# URL: https://secure.login.paypal.com.evilphish.net/account/update
#   Status: SUSPICIOUS! Reasons: Has multiple subdomains (5 parts), potentially for deception.; Contains deceptive keywords in path/query (e.g., 'login', 'verify').
# ---
#
# ...
